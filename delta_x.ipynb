# %%
import numpy as np
import matplotlib.pyplot as pit

# %% [markdown]
# # Definizione della funziona $f(x)$
#
# $f(x) = x^3 + x^2 - 5x + 2$

# %%
def f(x):
    return(x**3 + x**2 - 5*x + 2)

# %% [markdown]
# Genero il vettore degli argomenti $x$

# %%
x = np.linspace(-10 , 10 , 201)
# print(x)

# %%
# Traccio il grafico di f(x) limitato da -10 a 10 sia in x che in y, senza punti
import matplotlib.pyplot as plt
plt.plot(x, f(x))
plt.xlabel('x')
plt.ylabel('f(x)')
plt.title('Grafico di f(x) = x^3 + x^2 - 5x + 2')
plt.xlim(-10, 10)
plt.ylim(-10, 10)
plt.grid(True)
plt.show()

# %% [markdown]
# # Funzione pendenza $m(x)$

# %%
def m(x):
    dx=1e-5
    return (f(x+dx)-f(x-dx))/(2*dx)

# %%
# Calcolo la pendenza m(x) per tutti i valori di x
m_values = m(x)

# Traccio f(x) e m(x) sullo stesso grafico
plt.plot(x, f(x), label='f(x)')
for dx in [ 1e-9, 0.1, 0.25,  0.5, 1, 2,]:
    plt.plot(x, (f(x + dx) - f(x)) / dx, label=f'(x) approssimato con dx={dx}') 
plt.xlabel('x')
plt.ylabel('Valore')
plt.title('f(x) e m(x) per x in [-10, 10]')
plt.xlim(-10, 10)
plt.ylim(-10, 10)
plt.grid(True)
plt.legend()
plt.show()

# %%
# m(x) è la derivata numerica di f(x), che è un polinomio di terzo grado.
# Quindi m(x) è un polinomio di secondo grado: m(x) = 3x^2 + 2x - 5
# Troviamo i coefficienti tramite np.polyfit

coeff_m = np.polyfit(x, m_values, 2)
print("I coefficienti della parabola m(x) sono:", coeff_m)
# Out:
# I coefficienti della parabola m(x) sono: [ 3.  2. -5.]
